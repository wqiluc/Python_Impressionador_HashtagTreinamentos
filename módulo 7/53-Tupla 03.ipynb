# %% [markdown]
# # Aplicação de Tupla - Lista de Tuplas
#
# ### Estrutura:
#
# Além de casos como o do enumerate, em que usamos uma função para transformar itens em tuplas porque isso ajuda o nosso código, temos também listas de tuplas como algo comum dentro do Python.

# %% [raw]
# lista = [
#     tupla1,
#     tupla2,
#     tupla3,
#     ]
#
# ou seja
#
# lista = [
#     (valor1, valor2, valor3),
#     (valor4, valor5, valor6),
#     (valor7, valor8, valor9),
#     ]

# %% [markdown]
# ### Exemplo:
#
# Digamos que você está analisando as vendas do Banco de Dados de um e-commerce.
#
# Em um determinado dia, você extraiu as vendas do Banco de Dados e elas vieram nesse formato:

# %%
vendas = [
    ('20/08/2020', 'iphone x', 'azul', '128gb', 350, 4000),
    ('20/08/2020', 'iphone x', 'prata', '128gb', 1500, 4000),
    ('20/08/2020', 'ipad', 'prata', '256gb', 127, 6000),
    ('20/08/2020', 'ipad', 'prata', '128gb', 981, 5000),
    ('21/08/2020', 'iphone x', 'azul', '128gb', 397, 4000),
    ('21/08/2020', 'iphone x', 'prata', '128gb', 1017, 4000),
    ('21/08/2020', 'ipad', 'prata', '256gb', 50, 6000),
    ('21/08/2020', 'ipad', 'prata', '128gb', 4000, 5000),
]

# %% [markdown]
# - Qual foi o faturamento de IPhone no dia 20/08/2020?
# - Qual foi o produto mais vendido (em unidades) no dia 21/08/2020?

# %%
from cores import(Negrito,Reset,Verde)

for indice_venda, venda in enumerate(vendas):
    print(f"""{Negrito}{indice_venda+1}º produto: \n 
          Data: '{vendas[indice_venda][0]}', 
          Produto: '{vendas[indice_venda][1]}',  
          Cor: '{vendas[indice_venda][2]}', 
          Armazenamento: '{vendas[indice_venda][3]}',
          Quantidade de Vendidos:{Reset} {Verde}R${Reset}{Negrito}'{vendas[indice_venda][4]}', e
          Preço Total:{Reset}{Verde}R${Reset}{Negrito}'{vendas[indice_venda][5]}' \n """)

    #Se a Data = vendas[indice_venda][0] e(and) Produto = vendas[indice_venda][1], forem esses:
    if vendas[indice_venda][0] == "20/08/2020" and vendas[indice_venda][1] == "IPhone":
        print(f"{Negrito}Faturamento de IPhone em 20/08/2020:{Reset} {Verde}R${Reset}{Negrito}{vendas[indice_venda][5]}{Reset}\n")
    else:
        pass
    
    #Se a Data = vendas[indice_venda][0] for essa 👇:
    if vendas[indice_venda][0] == "21/08/2020":
        print(f"{Negrito}Produto mais vendido em 21/08/2020 (em unidades):{Reset} {Verde}{vendas[indice_venda][1]}{Reset}\n")
    else:
        pass
