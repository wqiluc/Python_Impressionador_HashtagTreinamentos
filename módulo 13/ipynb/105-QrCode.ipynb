# %% [markdown]
# # Criando QR Code

# %% [markdown]
# Links da Hashtag:
#
# - https://www.youtube.com/@HashtagProgramacao
# - https://www.facebook.com/hashtagprogramacao
# - https://www.instagram.com/hashtagprogramacao
# - https://www.youtube.com/@HashtagProgramacao
# - https://www.tiktok.com/@hashtagprogramacao

# %% [markdown]
# Para instalar:
#
# ```
# pip install qrcode
# pip install Pillow
# ```

# %% [markdown]
# ## QR Code simples

# %%
import qrcode

def generate_qr_code(data, filename):
    qr = qrcode.QRCode(
        version=1,
        error_correction=qrcode.constants.ERROR_CORRECT_L,
        box_size=10,
        border=4,
    )
    
    qr.add_data(data)
    qr.make(fit=True)

    img = qr.make_image(img="./img/logo.jpeg", fill_color="black", back_color="white")
    img.save(filename)

if (__name__ == "__main__"):
    data = "https://www.example.com"
    filename = "qr_code_exercicio1.png"
    generate_qr_code(data, filename)
    print(f"QR code gerado e salvo como: `{filename}`")

# %% [markdown]
# ## QR Code com imagem

# %%
import qrcode
from qrcode.image.pil import PilImage

def gerar_qr_code_imagem(data, filename):
    qr = qrcode.QRCode(
        version=1,
        error_correction=qrcode.constants.ERROR_CORRECT_L,
        box_size=10,
        border=4,
    )
    
    qr.add_data(data)
    qr.make(fit=True)

    img = qr.make_image(image_factory=PilImage, fill_color="black", back_color="white")
    img.save(filename)

if (__name__ == "__main__"):
    data = "https://www.youtube.com/@HashtagProgramacao"
    filename = "qr_code_exercicio2.png"
    gerar_qr_code_imagem(data, filename)
    display(f"QR code gerado e salvo como: `{filename}`")
# Out:
# QR code gerado e salvo como: `qr_code_exercicio2.png`

# %% [markdown]
# ## Criando diversos QR Code ao mesmo tempo

# %%
def gerar_multiplos_qr_codes(dados, prefixo_filename):
    for indice_data, data in enumerate(dados):
        nomedoarquivo = f"{prefixo_filename}_{indice_data+1}.jpeg"
        gerar_qr_code_imagem(data, nomedoarquivo)
        display(f"QR codes gerados e salvo como: `{nomedoarquivo}`")

def exibicao_qr_codes(nomedoarquivo):
    img = qrcode.make(nomedoarquivo)
    img.show()

if (__name__ == "__main__"):
    dados = [
        "https://www.youtube.com/@HashtagProgramacao",
        "https://www.instagram.com/hashtagprogramacao/",
        "https://www.linkedin.com/company/hashtag-programacao/"
    ]

    prefixo_filename = "qr_code_exercicio3"
    gerar_multiplos_qr_codes(dados, prefixo_filename)
