# %% [markdown]
# # for 🔃 + if ⬆
#
# ### Estrutura🏛️:

# %% [raw]
# for item in lista:
#     if condicao:
#         faça alguma coisa
#     else:
#         outra coisa

# %% [markdown]
# Digamos que a gente esteja analisando a meta de vendas de vários funcionários de uma empresa. A meta de vendas é de 1000 reais em 1 dia.
#
# Temos uma lista com as vendas de todos os funcionários e quero calcular qual o % de pessoas que bateram a meta.

# %%
vendas = [1200, 300, 800, 1500, 1900, 2750, 400, 20, 23, 70, 90, 80, 1100, 999, 900, 880, 870, 50, 1111, 120, 300, 450, 800]

qtd_meta = 0
meta = 1000
qtd_funcionarios = len(vendas)


for venda in (vendas):
    if venda>=meta:
        qtd_meta+=1
        print("\n O funcionário bateu a meta✅")
    else:
        pass

porcentagem_funcionarios_meta = qtd_meta/qtd_funcionarios

print(f"\n {qtd_meta} pessoas bateram a meta✅")
print(f"\n A porcentagem de funcionários que bateu a meta foi de: {porcentagem_funcionarios_meta*100:,.0f}%")
