# %% [markdown]
# # Formas de interromper um for
#
# ### 2 Opções:
#
# - break -> interrompe e finaliza o for
# - continue -> interrompe e vai para o próximo item do for

# %%
from cores import(Negrito,Reset,Verde,Vermelho)
vendas = [100, 150, 1500, 2000, 120]

# %% [markdown]
# - Caso 1: Se todas as vendas forem acima da meta, a loja ganha bônus 💰

# %%
meta = 110

for venda in (vendas):
    if venda<meta:
        print(venda)
        print(f"{Vermelho}A loja ganhou não ganhou bônus❌{Reset}")
        break

# %% [markdown]
# - Caso 2: Exiba quem bateu a meta

# %%
vendedores = ['João', 'Julia', 'Ana', 'José', 'Maria']
vendedores_e_vendas = [ ]
meta = 130


for indice, vendedor in enumerate(vendedores):
    vendedores_e_vendas.append([vendedor,vendas[indice]])

for vendedor, valor in vendedores_e_vendas:
    if valor>meta:
        print(f"{Negrito}vendedor(a): '{vendedor}', bateu a meta✅{Reset}")
        continue
