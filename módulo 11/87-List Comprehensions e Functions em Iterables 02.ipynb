# %% [markdown]
# # Um exemplo prático de List Comprehension
#
# ### O que faríamos se quisermos ordenar 2 listas "relacionadas"

# %%
vendas_produtos = [1500, 150, 2100, 1950]
produtos = ['vinho', 'cafeiteira', 'microondas', 'iphone']

lista_zipada = list(zip(produtos,vendas_produtos))
print(sorted(lista_zipada))

produtos = list(produtos for (produtos,venda)in (lista_zipada))
print(sorted(produtos[0:]))
