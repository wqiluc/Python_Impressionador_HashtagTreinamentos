# %% [markdown]
# ### Exercício 1
# Crie um sistema de consulta de preços
# Seu sistema deve:
# - Pedir para o usuário o nome de um produto
# - Caso o produto exista na lista de produtos, o programa deve retornar o preço do produto como resposta
#        - Ex: O produto celular custa R$1500
# - Caso o produto não exista na lista de produtos, o programa deve printar uma mensagem para o usuário tentar novamente

# %%
from cores import(Negrito,Reset,Vermelho,Verde)

precos = {"celular": 1500, "camera": 1000, "fone de ouvido": 800, "monitor": 2000}

usuario = str(input(f"{Negrito}Digite o nome de um produto da lista: {Reset}")).strip()
while not usuario.replace(" ", "").isalpha():
    print(f"{Vermelho}Termo Inválido!❌ Digite o nome de um produto da lista! {Reset}")
    usuario = str(input(f"{Negrito}Digite o nome de um produto da lista: {Reset}")).strip()
else:
    for produto,preco_produto in (enumerate(precos)):
        if (usuario.lower() in precos):
            print(f"{Negrito}O produto: '{usuario.lower()}'{Reset} {Verde}encontra-se na lista!✅🖋️{Reset} {Negrito}Preços a seguir:\n {precos}{Reset}")
            break
        else:
            print(f"{Negrito}O produto: '{usuario.lower()}'{Reset} {Vermelho}NÃO encontra-se na lista! 🖋️❌{Reset}")
            exit()

# %% [markdown]
# ### Exercício 2
# Agora edite o programa anterior para fazer com que, caso não exista o produto, o programa pergunte se o usuário quer cadastrar o produto
# <br>Se ele responder sim, o programa deve pedir o nome do produto e o preco do produto e cadastrar no dicionário de preços
# <br>Em seguida do cadastro bem sucedido, o programa deve printar o dicionário de precos atualizado

# %%
from cores import(Negrito,Reset,Vermelho,Verde)

precos = {"celular": 1500, "camera": 1000, "fone de ouvido": 800, "monitor": 2000}

usuario = str(input(f"{Negrito}Digite o nome de um produto da lista: {Reset}")).strip()
while not usuario.replace(" ", "").isalpha():
    print(TypeError)
    print(f"{Vermelho}Termo Inválido!❌ Digite o nome de um produto da lista! {Reset}")
    usuario = str(input(f"{Negrito}Digite o nome de um produto da lista: {Reset}")).strip()
else:
    for produto,preco_produto in (enumerate(precos)):
        if (usuario.lower() in precos):
            print(f"{Negrito}O produto: '{usuario.lower()}'{Reset} {Verde}encontra-se na lista!✅🖋️{Reset} {Negrito}Preços a seguir:\n {precos}{Reset}")
            break
    opcao = str(input(f"{Negrito}Deseja adicionar um produto a lista? [S / N]{Reset}")).strip().upper()
    if (opcao not in "SN"):
        print(f"{Vermelho}Termo Inválido!! Digite S/N{Reset}")
        opcao = str(input(f"{Negrito}Deseja adicionar um produto a lista? [S / N]{Reset}")).strip().upper()
    else:
        if (opcao=="N"):
            print(f"{Vermelho}Encerrando . . . 🖋️{Reset}")
            exit()
        else:
            nome_produto = str(input(f"{Negrito}Digite o nome do produto: {Reset}").strip().lower())
            while not (nome_produto.replace(" ", "").isalpha()):
                print(TypeError)
                print(f"{Vermelho}Nome inválido!❌{Reset}")
                nome_produto = input(f"{Negrito}Digite o nome do produto: {Reset}").strip().lower()

            preco_produto = str(input(f"{Negrito}Digite o preço do produto: {Reset}").strip())
            while not (preco_produto.replace(".", "", 1).isdigit()):
                print(TypeError)
                print(f"{Vermelho}Preço inválido!❌{Reset}")
                preco_produto = input(f"{Negrito}Digite o preço do produto: {Reset}").strip()

            precos[nome_produto.lower()] = float(preco_produto)
            print(f"{Verde}Produto cadastrado com sucesso!✅{Reset}")
            print(f"{Negrito}Dicionário de preços atualizado:{Reset}{Negrito}{precos}{Reset}")

# %% [markdown]
# ### Exercício 3
# Dada a lista de preços de produtos, uma loja resolveu fazer um reajuste nos preços dos produtos.
# calcule o novo valor dos produtos com base nas seguintes regras:
# - Preços até 1.000 vão ter um reajuste de 10% (ou seja, o novo preço será 110% do preço atual)
# - Preços até maiores que 1.000 até 2.000 vão ter reajuste de 15%
# - Preços acima de 2.000 vão ter reajuste de 20%

# %%
precos = {"celular": 1500, "camera": 1000, "fone de ouvido": 800, "monitor": 3000}

for indice_produto, produto in enumerate(precos.values()):
    print(f"{Negrito}{indice_produto+1}º Produto:{Reset} {Verde}R${Reset}{Negrito}{produto:<5}{Reset}")
    if (produto<=1000):
        produto = produto + (0.10*produto)
    elif (produto>1000 and produto<=2000):
        produto = produto + (0.15*produto)
    else:
        produto = produto + (0.20*produto)
    print(f"{Negrito}{indice_produto+1}º Produto novo preço:{Reset} {Verde}R${Reset}{Negrito}{produto:<5}{Reset}")

# %% [markdown]
# ### Exercício 4
#  - Edite o programa antigo para ter os 2 dicionários, o de preços originais e o de novos preços
#  - Em seguida calcule o valor total de reajuste em R$ que teve entre a lista de produtos original e a lista final

# %%
precos = {"celular": 1500, "camera": 1000, "fone de ouvido": 800, "monitor": 3000}

precos_reajustados = dict()

for indice_produto, (produto, valor) in enumerate(precos.items()):
    print(f"{Negrito}{indice_produto+1}º Produto:{Reset} {Verde}R${Reset}{Negrito}{valor:<5}{Reset}")

    if (valor <= 1000):
        novo_valor = valor * 1.10
    elif (valor <= 2000):
        novo_valor = valor * 1.15
    else:
        novo_valor = valor * 1.20

    precos_reajustados[produto.lower()] = novo_valor

    print(f"{Negrito}{indice_produto+1}º Produto novo preço:{Reset} {Verde}R${Reset}{Negrito}{novo_valor:<5.0f}{Reset}")

print(f"\n{Negrito}Dicionário com preços reajustados: 👇{Reset}")
print(precos_reajustados)

# %% [markdown]
# ### Exercício 5
# - Uma empresa está analisando os resultados de vendas do 1º semestre de 2022 e 2023
# - Qual foi o % de crescimento de cada mês de 2023 em relação a 2022?
# - Depois de calcular isso, calcule o valor total de crescimento de 2023 em relação a 2022

# %%
from cores import(Negrito,Reset,Verde)
vendas_22 = {"jan": 15000, "fev": 15500, "mar": 14000, "abr": 16600, "mai": 16300, "jun": 17000}
vendas_23 = {"jan": 17000, "fev": 15000, "mar": 17500, "abr": 16900, "mai": 16000, "jun": 18500}

print(vendas_22)
print(vendas_23)

vendas_crescimento = [ ]

# %% [markdown]
# ### Exercício 6 - Desafio
# - No final da reunião de apresentação dos números, seu chefe perguntou:
# - E se nos meses de 2023 que a gente vendeu menos do que 2022 a gente tivesse pelo menos empatado com 2022 (ou seja, se nos meses de 2023 em que as vendas foram menores do que o mesmo mês em 2022, o valor de vendas tivesse sido igual a 2022)
# - Qual teria sido o nosso crescimento de 2023 frente a 2022?
