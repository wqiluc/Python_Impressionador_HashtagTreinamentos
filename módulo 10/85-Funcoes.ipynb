# %% [markdown]
# ### Forma de pensar 💭

# %%
# Top -> Down

# Exemplo simples: atravessar a rua

# Desafio principal: atravessar a rua
# 1. Olhar para os dois lados
# 1.1 olhar pra direita e ver se tem carro vindo
# 1.2 olhar pra esquerda e ver se tem carro vindo
# 3. Se tiver carro, esperar
# 4. Se não tiver carro, atravessar a rua

# %% [markdown]
# ### Exemplo de Exercício do Curso

# %% [markdown]
# #### 23. Faça um Programa para uma loja de tintas. O programa deverá pedir o tamanho em metros quadrados da área a ser pintada. Considere que a cobertura da tinta é de 1 litro para cada 6 metros quadrados e que a tinta é vendida em latas de 18 litros, que custam R\\$ 80,00 ou em galões de 3,6 litros, que custam R\\$ 25,00.

# %%
from cores import *

def validar_dimensao(dimensao_area=0):
    dimensao_area = str(input(f"{Negrito}Qual a dimensão da área que você deseja pintar?{Reset}").strip().replace(",", "."))
    while not dimensao_area.replace('.', '', 1).isdigit():
        print(f"{Vermelho}Por favor, digite um número válido para a dimensão da área. (float){Reset}")
        dimensao_area = str(input(f"{Negrito}Qual a dimensão da área que você deseja pintar?{Reset}").strip().replace(",", "."))
    return float(dimensao_area)

def validar_preco(preco_lata=0):
    preco = str(preco_lata).replace(",", ".")
    while not preco.replace('.', '', 1).isdigit():
        print(f"{Vermelho}Preço inválido. Digite um número válido.{Reset}")
        preco = str(input(f"{Negrito}Informe o preço da lata:{Reset}").strip().replace(",", "."))
    return float(preco)

def principal():
    dimensao_area = validar_dimensao()
    preco_lata = validar_preco(80)

    litros_necessarios = dimensao_area / 6
    latas_necessarias = litros_necessarios / 18

    if (latas_necessarias > int(latas_necessarias)):
        latas_necessarias = int(latas_necessarias) + 1
    else:
        latas_necessarias = int(latas_necessarias)

    preco_total = latas_necessarias * preco_lata

    print(f"{Amarelo}=={Reset}"*30)
    print(f"{Negrito}Quantidade de latas de tinta necessárias:{Reset} {Amarelo}{latas_necessarias:.0f}{Reset}")
    print(f"{Negrito}Preço total:{Reset} {Verde}R${Reset}{Negrito} {preco_total:.2f}{Reset}")
    print(f"{Amarelo}=={Reset}"*30)

principal()

# %% [markdown]
# ##### Informe ao usuário as quantidades de tinta a serem compradas e os respectivos preços em 3 situações.
#
# Dica: lembre dos operadores // e % mostrados em exercícios anteriores<br>
# Dica1: numero // 10 vai te dar como resposta a parte inteira da divisão do número por 10. Ex: 7 // 3 = 2; 10 // 3 = 3<br>
# Dica2: numero % 10 vai te dar o resto da divisão do número por 10. Ex: 7 % 3 = 1; 10 % 3 = 1; 15 % 3 = 0
#
# ##### 1. Comprar apenas latas de 18 litros: (apenas latas inteiras)

# %%
def validar_dimensao(dimensao_area=0):
    while True:
        try:
            dimensao_area = float(input(f"{Negrito}Qual a dimensão da área que você deseja pintar?{Reset}").strip().replace(",", "."))
            return dimensao_area
        except ValueError:
            print(f"{ValueError}")
            print(f"{Vermelho}Por favor, digite um número válido para a dimensão da área. (float){Reset}")
        return dimensao_area
    
def validar_preco(preco_lata=18):
    return float(str(preco_lata).replace(",", "."))
   
    
def principal():
    dimensao_area = validar_dimensao()
    preco_lata = validar_preco(80)

    litros_necessarios = dimensao_area / 6
    latas_necessarias = litros_necessarios / 18

    if (latas_necessarias > int(latas_necessarias)):
        latas_necessarias = int(latas_necessarias) + 1
    else:
        latas_necessarias = int(latas_necessarias)

    preco_total = latas_necessarias * preco_lata

    print(f"{Amarelo}=={Reset}"*30)
    print(f"{Negrito}Quantidade de latas de tinta necessárias:{Reset} {Amarelo}{latas_necessarias:.0f}{Reset}")
    print(f"{Negrito}Preço total:{Reset} {Verde}R${Reset}{Negrito} {preco_total:.2f}{Reset}")
    print(f"{Amarelo}=={Reset}"*30) 

principal()

# %% [markdown]
# ##### 2. Comprar apenas galões de 3,6 litros: (apenas galoes inteiros)

# %%
from cores import *

def validar_dimensao(dimensao_area=0):
    while True:
        try:
            dimensao_area = float(input(f"{Negrito}Qual a dimensão da área que você deseja pintar?{Reset}").strip().replace(",", "."))
            return dimensao_area
        except ValueError:
            print(f"{Vermelho}Por favor, digite um número válido para a dimensão da área. (float){Reset}")

def validar_preco(preco_galoes=25):
    return float(str(preco_galoes).replace(",", "."))

def principal():
    dimensao_area = validar_dimensao()
    preco_galoes = validar_preco(25)

    litros_necessarios = dimensao_area / 6
    galoes_necessarios = litros_necessarios / 3.6

    if galoes_necessarios > int(galoes_necessarios):
        galoes_necessarios = int(galoes_necessarios) + 1
    else:
        galoes_necessarios = int(galoes_necessarios)

    preco_total = galoes_necessarios * preco_galoes

    print(f"{Amarelo}=={Reset}"*30)
    print(f"{Negrito}Quantidade de galões de tinta necessárias:{Reset} {Amarelo}{galoes_necessarios:.0f}{Reset}")
    print(f"{Negrito}Preço total:{Reset} {Verde}R${Reset}{Negrito} {preco_total:.2f}{Reset}")
    print(f"{Amarelo}=={Reset}"*30)

principal()

# %% [markdown]
# ##### 3. Misturar latas e galões, de forma que o desperdício de tinta seja menor. Sempre arredonde os valores para cima, isto é, considere latas cheias.

# %% [markdown]
# O custo da lata é 80/18 = 4,44 R\\$/L
#
# O custo do galão é 25/3,6 = 6,94 R\\$/L
#
# A lata é mais econômica, então todas as latas inteiras que pudermos usar devemos comprar em latas. Se ficar faltando alguma coisa para completar devemos avaliar se é melhor comprar latas ou galões. Exemplo:
#
# Se queremos comprar 90 litros. 5 latas dão exatamente 90 litros. Então devemos comprar tudo em latas.
#
# Se queremos comprar 95 litros. 5 latas dão exatamente 90 litros. Então devemos comprar pelo menos 5 latas e avaliar o que falta, se estes últimos 5 litros valem mais apenas em latas ou galões.
#
# Para os 5 litros faltantes precisamos de 2 galões que custam 50 reais no total. Ou de uma lata que custa 80 reais no total. Portanto, neste caso vale mais a pena usar 2 galões.
#
# Se queremos comprar 107 litros. 5 latas dão exatamente 90 litros. Então devemos comprar pelo menos 5 latas e avaliar o que falta, se estes últimos 5 litros valem mais apenas em latas ou galões.
#
# Para os 17 litros faltantes precisamos de 5 galões que custam 125 reais no total. Ou de uma lata que custa 80 reais no total. Portanto, neste caso vale mais a pena usar uma lata.
#
# 3 galões custam 75 reais, 4 galões custam 100 reais. Então, se for possível completar com até 3 galões escolhe-se galões. Qualquer quantidade maior que 3 galões, usa-se latas.
#
# Podemos ir ao exercício:

# %%
# 1. Pegar a dimensão da área a ser pintada
def validar_dimensao(dimensao_area=0):
    while True:
        try:
            dimensao_area = float(input(f"{Negrito}Qual a dimensão da área que você deseja pintar?{Reset}").strip().replace(",", "."))
            return dimensao_area
        except ValueError:
            print(f"{Vermelho}Por favor, digite um número válido para a dimensão da área. (float){Reset}")
# 2. Pegar quantos litros eu vou precisar
def calcular_litros_necessarios(dimensao_area, litros_necessarios=0):
    litros_necessarios = dimensao_area / 6 
    return litros_necessarios
# 3. Pegar quantos galões de tinta eu vou precisar
    #3.1 Calcular quantas latas inteiras eu vou precisar
    #3.2 Se tiver latas fracionadas, arredondar para cima
    #3.3 Calcular quantos litros faltam preencher por lata ou galão
    #3.4 Escolher a opcão mais barata!
# 4. Calcular o preço total
def calcular_custo(latas, galoes):
    custo_lata = latas*80
    custo_galoes = galoes*25
    custo_total = custo_lata+custo_galoes
    return custo_total

# %%
from cores import *

def validar_dimensao():
    while True:
        try:
            return float(input(f"{Negrito}Qual a dimensão da área que você deseja pintar?{Reset}").strip().replace(",", "."))
        except ValueError:
            print(f"{Vermelho}Por favor, digite um número válido para a dimensão da área. (float){Reset}")

def calcular_custo(latas,galoes):
    return latas*80+galoes*25

area = validar_dimensao()
litros = area/6
latas = int(litros/18)
galoes = 0
litros_faltam = litros % 18

#se for preencher com latas:
custo_extra_em_latras = 80
#se for preencher com galões:
galoes = int(litros_faltam/3.6)

if (litros_faltam%3.6>0):
    galoes+=1
custo_extra_em_galoes = galoes*25

if (custo_extra_em_latras<custo_extra_em_galoes):
    latas+=1
    galoes=0

custo = calcular_custo(latas,galoes)

latas_inteiras = int(litros/18)
print(latas_inteiras)
print(litros)
print(litros_faltam)
print(f"{Amarelo}=={Reset}"*30)
print(f"{Negrito}Latas:{Reset} {Amarelo}{latas:.0f}{Reset}")
print(f"{Negrito}Galões:{Reset} {Amarelo}{galoes:.0f}{Reset}")
print(f"{Negrito}Preço total:{Reset} {Verde}R${Reset}{Negrito} {custo:.2f}{Reset}")
print(f"{Amarelo}=={Reset}"*30)
