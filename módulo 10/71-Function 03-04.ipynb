# %% [markdown]
# # Argumentos/Parâmetros da Função
#
# ### Estrutura:

# %% [raw]
# def minha_funcao(parametro1, parametro2, parametro3):
#     return parametro1 + parametro2 + parametro3

# %% [markdown]
# - Exemplo: nosso famoso print

# %%
from cores import(Negrito,Reset,Vermelho)
mensagens = [ ]

def exibir(mensagem= " "):
    mensagem = str(input("Diga algo: ")).strip().capitalize().split()
    return mensagem
mensagem_usuario = exibir()
mensagens.append(mensagem_usuario[0])
print(mensagens)

# %% [markdown]
# - Só para mostrar o funcionamento, vamos criar uma função de soma

# %%
def somar_numeros(num1=0,num2=0):
    num1 = str(input(f"{Negrito}Digite o 1º número: {Reset}")).strip()
    while not num1.isdigit():
        print(TypeError)
        print(f"{Vermelho}Termo Inválido!! ❌ Digite um número (int){Reset}")
        num1 = str(input(f"{Negrito}Digite o 1º número: {Reset}")).strip()
    num1 = int(num1)
    num2 = str(input(f"{Negrito}Digite o 1º número: {Reset}")).strip()
    while not num2.isdigit():
        print(TypeError)
        print(f"{Vermelho}Termo Inválido!! ❌ Digite um número (int){Reset}")
        num2 = str(input(f"{Negrito}Digite o 1º número: {Reset}")).strip()
    num2 = int(num2)
    soma = num1+num2
    return soma

resultado = somar_numeros()
print(f"O resultado da soma é: {resultado}")

# %% [markdown]
# - Vamos criar uma function com parâmetro
#
# Digamos que estamos criando um programa para categorizar os produtos de uma revendedora de bebidas.
#
# Cada produto tem um código. O tipo de produto é dado pelas 3 primeiras letras do código.
#
# Ex:<br>
# Vinho -> BEB12302<br>
# Cerveja -> BEB12043<br>
# Vodka -> BEB34501<br>
#
# Guaraná -> BSA11104<br>
# Coca -> BSA54301<br>
# Sprite -> BSA34012<br>
# Água -> BSA09871<br>
#
# Repare que bebidas não alcóolicas começam com BSA e bebidas alcoolicas começam com BEB.
#
# Crie um programa que analise uma lista de produtos e envie instruções para a equipe de estoque dizendo quais produtos devem ser enviados para a área de bebidas alcóolicas.

# %%
produtos = ['BEB46275','TFA23962','TFA64715','TFA69555','TFA56743','BSA45510','TFA44968','CAR75448','CAR23596','CAR13490','BEB21365','BEB31623','BSA62419','BEB73344','TFA20079','BEB80694','BSA11769','BEB19495','TFA14792','TFA78043','BSA33484','BEB97471','BEB62362','TFA27311','TFA17715','BEB85146','BEB48898','BEB79496','CAR38417','TFA19947','TFA58799','CAR94811','BSA59251','BEB15385','BEB24213','BEB56262','BSA96915','CAR53454','BEB75073']

produtos_BEB = list()

def bebidas():
    for indice_produto, (produto) in (enumerate(produtos)):
        if produto.startswith("Beb".upper()):
            produtos.remove(produto)
            produtos_BEB.append(produto)

    for indice_bebidas_nao_alcoolicas, (bebidas_nao_alcoolicas) in enumerate(produtos): 
        print(f"\n {Negrito}{indice_bebidas_nao_alcoolicas+1}º Produto não-alcóolico: {bebidas_nao_alcoolicas[0:]}{Reset}")

    for indice_bebidas_alcoolicas, (bebidas_alcoolicas) in (enumerate(produtos_BEB)):
        print(f"\n {Negrito}{indice_bebidas_alcoolicas+1}º Produto alcóolico: {bebidas_alcoolicas[0:]}{Reset}")

estoque_separacao = bebidas()
print(estoque_separacao)
# Out:
#  1º Produto não-alcóolico: TFA23962
#
#  2º Produto não-alcóolico: TFA64715
#
#  3º Produto não-alcóolico: TFA69555
#
#  4º Produto não-alcóolico: TFA56743
#
#  5º Produto não-alcóolico: BSA45510
#
#  6º Produto não-alcóolico: TFA44968
#
#  7º Produto não-alcóolico: CAR75448
#
#  8º Produto não-alcóolico: CAR23596
#
#  9º Produto não-alcóolico: CAR13490
#
#  10º Produto não-alcóolico: BEB31623
#
#  11º Produto não-alcóolico: BSA62419
#
#  12º Produto não-alcóolico: TFA20079
#
#  13º Produto não-alcóolico: BSA11769
#
#  14º Produto não-alcóolico: TFA14792
#
#  15º Produto não-alcóolico: TFA78043
#
#  16º Produto não-alcóolico: BSA33484
#
#  17º Produto não-alcóolico: BEB62362
#
#  18º Produto não-alcóolico: TFA27311
#
#  19º Produto não-alcóolico: TFA17715
#
#  20º Produto não-alcóolico: BEB48898
#
#  21º Produto não-alcóolico: CAR38417
#
#  22º Produto não-alcóolico: TFA19947
#
#  23º Produto não-alcóolico: TFA58799
#
#  24º Produto não-alcóolico: CAR94811
#
# ...
