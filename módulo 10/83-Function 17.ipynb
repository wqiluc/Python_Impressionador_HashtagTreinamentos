# %% [markdown]
# # Ordem dos Argumentos
#
# ### Estrutura🏛️:
#
# 1. Sempre os positional arguments vêm antes e depois os keywords arguments.
# 2. Sempre os argumentos individuais vêm antes e depois os "múltiplos"

# %% [raw]
# def minha_funcao(arg1, arg2, arg3, arg4, *args, k = kwarg1, k2 = kwarg2, k3 = kwarg3, **kwargs):
#     ...

# %%
def minhas_soma(*numeros, inicio=0):
    total = inicio
    for numero in numeros:
        total += numero
    print(total)
    return total
minhas_soma(1, 2, 3, inicio=2)
# Out:
# 8
# 8
