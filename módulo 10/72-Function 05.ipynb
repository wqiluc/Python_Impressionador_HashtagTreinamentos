# %% [markdown]
# # Mais de 1 argumento e formas de passar argumento para uma função
#
# ### Estrutura🏛️:
#
# - 2 formas de passar o argumento:
#     1. Em ordem (positional argument)
#     2. Com o nome do argumento (keyword argument)

# %% [markdown]
# - Vamos mudar a função que fizemos na aula passada para conseguir categorizar qualquer tipo de bebida de acordo com o "rótulo" passado para a nsosa function. Basicamente nossa function agora tem que verificar se o produto é da categoria passada ou não.

# %%
from cores import(Negrito,Reset,Verde)

def eh_da_categoria(bebida,codcategoria):
    bebida = bebida.upper()
    if codcategoria in (bebida):
        return True
    else:
        return False


produtos = ['CAR46275','TFA23962','TFA64715','TFA69555','TFA56743','BSA45510','TFA44968','CAR75448','CAR23596','CAR13490','BEB21365','BEB31623','BSA62419','BEB73344','TFA20079','BEB80694','BSA11769','BEB19495','TFA14792','TFA78043','BSA33484','BEB97471','BEB62362','TFA27311','TFA17715','BEB85146','BEB48898','BEB79496','CAR38417','TFA19947','TFA58799','CAR94811','BSA59251','BEB15385','BEB24213','BEB56262','BSA96915','CAR53454','BEB75073']

for indice_produto, produto in enumerate(produtos):
    if eh_da_categoria(produto, "BEB"):
        print(f"""{Negrito}{indice_produto+1}º Produto Alcóolico: {produto} -{Reset} {Verde}Enviar para setor de bebidas alcóolicas📦{Reset}""")
# Out:
# 11º Produto Alcóolico: BEB21365 - Enviar para setor de bebidas alcóolicas📦
# 12º Produto Alcóolico: BEB31623 - Enviar para setor de bebidas alcóolicas📦
# 14º Produto Alcóolico: BEB73344 - Enviar para setor de bebidas alcóolicas📦
# 16º Produto Alcóolico: BEB80694 - Enviar para setor de bebidas alcóolicas📦
# 18º Produto Alcóolico: BEB19495 - Enviar para setor de bebidas alcóolicas📦
# 22º Produto Alcóolico: BEB97471 - Enviar para setor de bebidas alcóolicas📦
# 23º Produto Alcóolico: BEB62362 - Enviar para setor de bebidas alcóolicas📦
# 26º Produto Alcóolico: BEB85146 - Enviar para setor de bebidas alcóolicas📦
# 27º Produto Alcóolico: BEB48898 - Enviar para setor de bebidas alcóolicas📦
# 28º Produto Alcóolico: BEB79496 - Enviar para setor de bebidas alcóolicas📦
# 34º Produto Alcóolico: BEB15385 - Enviar para setor de bebidas alcóolicas📦
# 35º Produto Alcóolico: BEB24213 - Enviar para setor de bebidas alcóolicas📦
# 36º Produto Alcóolico: BEB56262 - Enviar para setor de bebidas alcóolicas📦
# 39º Produto Alcóolico: BEB75073 - Enviar para setor de bebidas alcóolicas📦

# %% [markdown]
# <strong>Obs Importante: Sua função deve estar SEMPRE antes de ser usada.</strong>
#
# - <strong>Normalmente, nos nossos códigos, fazemos as definições de todas as funções antes e depois construimos o resto do código✅.</strong>
# - <strong>É comum dar '2 enters' após a definição da função para deixar o código mais organizado</strong>
