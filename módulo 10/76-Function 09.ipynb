# %% [markdown]
# # Mais sobre o return🔂
#
# <strong>Pontos importantes⚠️:</strong>
#
# - Podemos usar no return praticamente qualquer tipo de objeto: (número, string, lista, tupla, dicionário, outros objetos, etc.)
# - O return, se for executado, encerra a função, mesmo que dentro dela haja um loop.

# %%
#retornar um número:
def minha_soma(num1, num2, num3):
    return num1 + num2 + num3

#retornar um texto:
def padronizar_texto(texto):
    texto = texto.casefold()
    texto = texto.replace("  ", " ")
    texto = texto.strip()
    return texto

#retornar um booleano:
def bateu_meta(vendas, meta):
    if (vendas >= meta):
        return True
    else:
        return False
    
#retornar uma lista [ ], tupla ( ) ou dicionario { }:
def filtrar_lista_texto(lista, pedaco_texto):
    lista_filtrada = [ ]
    for indice_item, item in enumerate(lista):
        if pedaco_texto in (item):
            lista_filtrada.append(item)
            return lista_filtrada

# %%
from cores import(Negrito,Reset,Verde)
emails = [
    "ricardo.moura@hotmail.com",
    "ana.silva@gmail.com",
    "aline.barros@yahoo.com",
    "bruno.costa@gmail.com",
    "thiago.farias@outlook.com",
    "carla.mendes@gmail.com",
    "beatriz.lopes@icloud.com",
    "diego.rocha@gmail.com",
    "lucas.pacheco@protonmail.com",
    "eduarda.lima@gmail.com",
    "camila.ramos@zoho.com",
    "felipe.santos@gmail.com",
    "rafael.dantas@aol.com",
    "gabriela.pereira@gmail.com",
    "juliana.borges@yandex.com",
    "henrique.alves@gmail.com",
    "vinicius.araujo@mail.com",
    "isabela.freitas@gmail.com",
    "patricia.gomes@uol.com.br",
    "joao.ribeiro@gmail.com",
    "andre.maciel@bol.com.br",
    "larissa.martins@gmail.com",
    "renata.torres@terra.com.br",
    "marcos.teixeira@gmail.com",
    "gustavo.meireles@fastmail.com",
    "natalia.azevedo@gmail.com",
    "monica.peixoto@tutanota.com",
    "otavio.nogueira@gmail.com",
    "daniel.siqueira@outlook.com",
    "paula.campos@gmail.com"]

def filtrar_gmail(emails):
    lista_filtrada = list()

    for indice_emails_gmail, (email_gmail) in enumerate(sorted(emails)):
        if "Gmail".lower() in (email_gmail):
            lista_filtrada.append(email_gmail)
            print(f"{Negrito}{indice_emails_gmail + 1}º Email: '{email_gmail}' - {Reset}{Verde}É gmail ✅🖋️{Reset}")
    return lista_filtrada

emails_filtrados = filtrar_gmail(emails)
