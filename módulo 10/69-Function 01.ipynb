# %% [markdown]
# # Function Python🗽
#
# ### O que é❓
#
# As functions são blocos de código que servem 1 único propósito: <strong>fazem uma ação específica.</strong>
#
# ### Estrutura Básica🏛️:

# %% [raw]
# def nome_funcao():
#     faça alguma coisa
#     faça outra coisa
#     return valor_final

# %% [markdown]
# - Exemplo: vamos criar uma função de cadastro de um Produto. Essa função deve garantir que o produto cadastrado está em letra minúscula.

# %%
from cores import (Negrito, Reset, Verde, Vermelho)

def entrada_produto(nome=" ".lower(), preco=0):
    nome = str(input(f"{Negrito}Digite o nome do Produto: {Reset}")).strip()
    preco = str(input(f"{Negrito}Digite o preço do produto: '{nome}': {Reset}"))
    return nome, preco

def validacao_produto(nome, preco):
    while not nome.isalpha():
        print(TypeError)
        print(f"{Vermelho}Termo Inválido!! ❌ Digite o NOME de um produto (str){Reset}")
        nome = str(input(f"{Negrito}Digite o nome do Produto: {Reset}")).strip()
    print(f"{Negrito}Produto: '{nome}'{Reset} {Verde}cadastrado! ✅🖋️{Reset}")

    while not preco.isdigit():
        print(TypeError)
        print(f"{Vermelho}Termo Inválido!! ❌ Digite o PREÇO do produto (int){Reset}")
        preco = str(input(f"{Negrito}Digite o preço do produto: '{nome}': {Reset}"))
    print(f"{Negrito}Preço: '{preco}'{Reset} {Verde}cadastrado! ✅🖋️{Reset}")
    
    return nome.lower(), int(preco)

def cadastro_produto():
    nome, preco = entrada_produto()
    nome, preco = validacao_produto(nome, preco)
    print(f"\n {Negrito}Produto: '{nome}', Preço:{Reset} {Verde}R${Reset}{Negrito}{preco}{Reset}")

cadastro_produto()
