# %% [markdown]
# # Retornar um valor na Function Python🔄
#
# ### Estrutura Básica🏛️

# %% [raw]
# def nome_funcao():
#     return valor_final

# %% [markdown]
# - Exemplo: vamos criar uma função de cadastro de um Produto. Essa função deve garantir que o produto cadastrado está em letra minúscula.

# %%
def cadastrar_produto(produto=" "):
    produto = str(input('Digite o nome do produto que deseja cadastrar')).capitalize().strip().split()
    return produto

varival_produto = cadastrar_produto()
print(varival_produto)

# Variáveis dentro do def função, APENAS EXISTEM DENTRO DELA. (Variáveis locais!)
