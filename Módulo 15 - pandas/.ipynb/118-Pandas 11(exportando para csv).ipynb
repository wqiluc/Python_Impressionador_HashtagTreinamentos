# %% [markdown]
# # 📤 Exportando DataFrames para CSV
#
# ![Jupyter](https://img.shields.io/badge/Jupyter-111827?style=flat-square&logo=jupyter&logoColor=F37626)
# ![Python](https://img.shields.io/badge/Python-111827?style=flat-square&logo=python&logoColor=3776AB)
# ![Pandas](https://img.shields.io/badge/Pandas-150458?style=flat-square&logo=pandas&logoColor=white)
# ![Python Version](https://img.shields.io/badge/python-3.14+-blue)
# ![Tópico](https://img.shields.io/badge/tópico-exportação%20%7C%20csv-teal)
# ![Dificuldade](https://img.shields.io/badge/dificuldade-Intermediário-yellow)
# ![Pré-req](https://img.shields.io/badge/pré--req-dataframe%20%7C%20merge-purple)
# ![Biblioteca](https://img.shields.io/badge/requer-pip%20install%20pandas-orange)
#
# > Depois de modificar um DataFrame, ou até criar um do zero, muitas vezes precisamos exportar esse resultado para um arquivo `.csv` — seja para compartilhar, seja para usar em outra ferramenta.
#
#
# ## 📋 Conteúdo
#
# 1. [Preparando as bases de dados](#️-1-preparando-as-bases-de-dados)
# 2. [Exportando um DataFrame para csv](#-2-exportando-um-dataframe-para-csv)
# 3. [Criando um DataFrame a partir de um dicionário](#-3-criando-um-dataframe-a-partir-de-um-dicionário)
# 4. [Exportando o novo DataFrame para csv](#-4-exportando-o-novo-dataframe-para-csv)
#
# ---
#
# ## ⚙️ 1. Preparando as bases de dados

# %% [markdown]
# - Preparando as bases de dados (o que fizemos nas últimas aulas)

# %%
import pandas as pd

# importando os arquivos
vendas_df = pd.read_csv(r'../spec/Contoso - Vendas - 2017.csv', sep=';', encoding='latin1')
produtos_df = pd.read_csv(r'../spec/Contoso - Produtos Cadastro Completo.csv', sep=';', encoding='latin1')
lojas_df = pd.read_csv(r'../spec/Contoso - Lojas.csv', sep=';', encoding='latin1')
clientes_df = pd.read_csv(r'../spec/Contoso - Clientes.csv', sep=';', encoding='latin1')

# Ajustar nome das colunas
produtos_df.rename(columns={'ÿNome do Produto': 'Nome do Produto'}, inplace=True)
clientes_df.rename(columns={'ÿID Cliente': 'ID Cliente'}, inplace=True)
lojas_df.rename(columns={'ÿID Loja': 'ID Loja'}, inplace=True)

# limpando apenas as colunas que queremos
clientes_df = clientes_df[['ID Cliente', 'E-mail']]
produtos_df = produtos_df[['ID Produto', 'Nome do Produto']]
lojas_df = lojas_df[['ID Loja', 'Nome da Loja']]

# mesclando e renomeando os dataframes
vendas_df = vendas_df.merge(produtos_df, on='ID Produto')
vendas_df = vendas_df.merge(lojas_df, on='ID Loja')
vendas_df = vendas_df.merge(clientes_df, on='ID Cliente').rename(columns={'E-mail': 'E-mail do Cliente'})

display(vendas_df.head())
# Out:
#    Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  ID Produto  \
# 0                1    01/01/2017    02/01/2017         1       86         981
# 1                2    01/01/2017    06/01/2017         5      308        1586
# 2                3    01/01/2017    01/01/2017         0      294        1444
# 3                4    01/01/2017    01/01/2017         0      251        1468
# 4                5    01/01/2017    07/01/2017         6       94        1106
#
#    ID Promocao  ID Cliente  Quantidade Vendida  Quantidade Devolvida  \
# 0            2        6825                   9                     1
# 1            2       18469                   9                     1
# 2            5       19730                  13                     1
# 3            5       29326                   6                     1
# 4            2       22617                   4                     1
#
#                                      Nome do Produto  \
# ...

# %% [markdown]
# ## 💾 2. Exportando um DataFrame para csv
#
# No pandas, exportar um DataFrame para `.csv` é bem simples: basta chamar `.to_csv()`.
#
# ```python
# dataframe.to_csv('nome_do_arquivo.csv', sep=';')
# ```
#
# | Parâmetro | O que faz |
# |-----------|-----------|
# | `'nome_do_arquivo.csv'` | Caminho/nome do arquivo que será criado |
# | `sep=';'` | Define o separador de colunas (o mesmo que usamos para ler os csv do curso) |
# | `index=False` | Evita exportar o índice do DataFrame como uma coluna extra |
#
# > 💡 **Dica:** vamos salvar o resultado dentro da pasta `spec`, junto com as demais bases do módulo.

# %%
# exportando o DataFrame consolidado de vendas para a pasta spec
vendas_df.to_csv('../spec/Contoso - Vendas Consolidado.csv', sep=';', index=False)

# %% [markdown]
# ## 📦 3. Criando um DataFrame a partir de um dicionário
#
# Nem sempre os dados vêm de um `.csv` — às vezes já temos as informações em um dicionário Python e queremos transformá-las em um DataFrame para depois exportar.
#
# No pandas, isso é bem simples:
#
# ```python
# variavel = pd.DataFrame.from_dict(dicionario)
# ```
#
# | Parâmetro | O que faz |
# |-----------|-----------|
# | `dicionario` | Dicionário Python com os dados de origem |
# | `orient='index'` | Usa as **chaves** do dicionário como índice (linhas) em vez de colunas |
# | `columns=[...]` | Nomeia as colunas criadas a partir das listas de valores |
#
# Cada produto do dicionário abaixo tem uma lista com 2 valores: a quantidade vendida e a quantidade devolvida.

# %%
vendas_produtos = {'iphone': [558147, 951642], 'galaxy': [712350, 244295], 'ipad': [573823, 26964], 'tv': [405252, 787604], 'máquina de café': [718654, 867660], 'kindle': [531580, 78830], 'geladeira': [973139, 710331], 'adega': [892292, 646016], 'notebook dell': [422760, 694913], 'notebook hp': [154753, 539704], 'notebook asus': [887061, 324831], 'microsoft surface': [438508, 667179], 'webcam': [237467, 295633], 'caixa de som': [489705, 725316], 'microfone': [328311, 644622], 'câmera canon': [591120, 994303]}

vendas_produtos_df = pd.DataFrame.from_dict(vendas_produtos, orient='index', columns=['Quantidade Vendida', 'Quantidade Devolvida'])
vendas_produtos_df.index.name = 'Produto'

display(vendas_produtos_df)
# Out:
#                    Quantidade Vendida  Quantidade Devolvida
# Produto
# iphone                         558147                951642
# galaxy                         712350                244295
# ipad                           573823                 26964
# tv                             405252                787604
# máquina de café                718654                867660
# kindle                         531580                 78830
# geladeira                      973139                710331
# adega                          892292                646016
# notebook dell                  422760                694913
# notebook hp                    154753                539704
# notebook asus                  887061                324831
# microsoft surface              438508                667179
# webcam                         237467                295633
# caixa de som                   489705                725316
# ...

# %% [markdown]
# ## 🎯 4. Exportando o novo DataFrame para csv
#
# Agora que temos o DataFrame `vendas_produtos_df`, vamos exportá-lo do mesmo jeito que fizemos antes — direto para a pasta `spec`.
#
# > ⚠️ **Cuidado:** como aqui o índice (`Produto`) tem informação relevante, **não** usamos `index=False` — dessa vez queremos manter o índice no csv exportado.

# %%
# exportando o DataFrame criado a partir do dicionário para a pasta spec
vendas_produtos_df.to_csv('../spec/Vendas Produtos.csv', sep=';')
