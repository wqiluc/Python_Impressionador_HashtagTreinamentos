# %% [markdown]
# # Listas em Python
#
# ## Estrutura:
#
# lista = [valor, valor, valor, valor, ...]
#
# lista[i] -> é o valor de índice i da lista. <br>
# Obs: Lembre que no python o índice começa em 0, então o primeiro item de uma lista é o item lista[0]
#
# Para substituir um valor de uma lista você pode fazer:<br>
# lista[i] = novo_valor
#
# Listas de Produtos de uma Loja:

# %%
produtos = ['tv', 'celular', 'mouse', 'teclado', 'tablet']

# %% [markdown]
# Lista de Unidades Vendidas de cada Produto da Loja

# %%
vendas = [1000, 1500, 350, 270, 900]

# %% [markdown]
# ### Nesse caso, as listas funcionam da seguinte forma:

# %% [raw]
# produtos = ['tv', 'celular', 'mouse', 'teclado', 'tablet']
#               0 ,      1   ,    2   ,     3    ,     4
# vendas = [  1000,    1500  ,   350  ,    270   ,    900  ]

# %%
from cores import (Negrito, Reset, Verde)

produtos = ['tv', 'celular', 'mouse', 'teclado', 'tablet']
vendas = [1000, 1500, 350, 270, 900]

print(f"{Negrito}A {produtos[0]} vendeu:{Reset} {Verde}R${Reset}{vendas[0]},00{Reset}")
print(f"{Negrito}O {produtos[1]} vendeu:{Reset} {Verde}R${Reset}{vendas[1]},00{Reset}")
print(f"{Negrito}O {produtos[2]} vendeu:{Reset} {Verde}R${Reset}{vendas[2]},00{Reset}")
print(f"{Negrito}O {produtos[3]} vendeu:{Reset} {Verde}R${Reset}{vendas[3]},00{Reset}")
print(f"{Negrito}O {produtos[4]} vendeu:{Reset} {Verde}R${Reset}{vendas[4]},00{Reset}")

# %%
texto = 'lira@gmail.com'
